# %% [markdown]
# Есть набор данных о стоимости недвижимости в Великобритании - .csv файл (описание столбцов тут https://www.gov.uk/guidance/about-the-price-paid-data)
# нужно написать программу, которая сформирует файл, в котором будет перечислена вся недвижимость, проданная больше 1-го раза.
# Программа должна потреблять как можно меньше вычислительных ресурсов. Рассмотреть случаи экономии памяти и процессорного времени.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Анализ с помощью pandas

# %%
import pandas as pd

# %%
#Датасет достаточно большой и не загружается в память полностью(по крайней мере с 12 gb ram в google colab). 
#Поэтому загружаем только нужные для анализа колонки
#Это id транзакции, тип транзакции(PPD Category Type), статус записи(Record Status), а также тип собственности и ее адрес.
#Будем считать, что собственность полностью характеризуется адресом и типом
#(адрес может меняться, но учесть это только с помощью этого датасета невозможно) 
df0 = pd.read_csv('/content/drive/MyDrive/datasets/pp-complete.csv', header=None, usecols=[0, 4,7, 8,9,10,11,12,13,14,15])

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26541204 entries, 0 to 26541203
# Data columns (total 11 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       object
#  1   4       object
#  2   7       object
#  3   8       object
#  4   9       object
#  5   10      object
#  6   11      object
#  7   12      object
#  8   13      object
#  9   14      object
#  10  15      object
# dtypes: object(11)
# memory usage: 2.2+ GB

# %%
#Вставляем оригинальные названия колонок
df0.rename(columns={
    0: 'id',
    4: 'Property Type',
    7: 'PAON',
    8: 'SAON',
    9: 'Street', 
    10: 'Locality', 
    11: 'Town/City', 
    12: 'District',
    13: 'County', 
    14: 'PPD Category Type', 
    15: 'Record Status'}, inplace=True)

# %%
df0.head()
# Out:
#                                        id Property Type PAON SAON  \
# 0  {F887F88E-7D15-4415-804E-52EAC2F10958}             D   31  NaN
# 1  {40FD4DF2-5362-407C-92BC-566E2CCE89E9}             T   50  NaN
# 2  {7A99F89E-7D81-4E45-ABD5-566E49A045EA}             T   19  NaN
# 3  {28225260-E61C-4E57-8B56-566E5285B1C1}             T   37  NaN
# 4  {444D34D7-9BA6-43A7-B695-4F48980E0176}             S   59  NaN
#
#              Street       Locality      Town/City       District  \
# 0     ALDRICH DRIVE         WILLEN  MILTON KEYNES  MILTON KEYNES
# 1       HOWICK PARK     SUNDERLAND     SUNDERLAND     SUNDERLAND
# 2  BRICK KILN CLOSE     COGGESHALL     COLCHESTER      BRAINTREE
# 3  RAINSBROOK DRIVE        SHIRLEY       SOLIHULL       SOLIHULL
# 4        MERRY HILL  BRIERLEY HILL  BRIERLEY HILL         DUDLEY
#
#           County PPD Category Type Record Status
# 0  MILTON KEYNES                 A             A
# 1  TYNE AND WEAR                 A             A
# 2          ESSEX                 A             A
# 3  WEST MIDLANDS                 A             A
# 4  WEST MIDLANDS                 A             A

# %%
#Пропущенные значения встречаются в адресе собственности. 
#Считаем, что это нормально, например у частного дома нет адреса квартиры(SAON) и т.д.
df0.isna().sum()
# Out:
# id                          0
# Property Type               0
# PAON                     4194
# SAON                 23445666
# Street                 416293
# Locality              9004011
# Town/City                   0
# District                    0
# County                      0
# PPD Category Type           0
# Record Status               0
# dtype: int64

# %% [markdown]
# рассмотрим технические колонки PPD Category Type и Record Status

# %%
df0['Record Status'].value_counts()
# Out:
# A    26541204
# Name: Record Status, dtype: int64

# %% [markdown]
# В Record Status нет значений 'C' и 'D', то есть нет пометок на удаление и изменение данных. Соответственно, не нужно удалять строки. Дополнительно проверим транзакции на уникальность id

# %%
df0['id'].is_unique
# Out:
# True

# %%
df0['PPD Category Type'].value_counts()
# Out:
# A    25549153
# B      992051
# Name: PPD Category Type, dtype: int64

# %%
#Таким образом можно уменьшить объем занимаемый датасетом,
#удалив ненужные колонки(или в принципе не загружать их изначально)
df0.drop(labels=['id', 'Record Status', 'PPD Category Type'],axis = 1)
# Out:
#          Property Type          PAON    SAON            Street       Locality  \
# 0                    D            31     NaN     ALDRICH DRIVE         WILLEN
# 1                    T            50     NaN       HOWICK PARK     SUNDERLAND
# 2                    T            19     NaN  BRICK KILN CLOSE     COGGESHALL
# 3                    T            37     NaN  RAINSBROOK DRIVE        SHIRLEY
# 4                    S            59     NaN        MERRY HILL  BRIERLEY HILL
# ...                ...           ...     ...               ...            ...
# 26541199             D            40     NaN    FLAT HOLM WALK          SULLY
# 26541200             D  LINDERIC, 2B     NaN         PANT GLAS            NaN
# 26541201             D             3     NaN      CLOS OAKDALE       GELLIHAF
# 26541202             D            32     NaN      MELROSE WALK          SULLY
# 26541203             F   PLAS ELYRCH  FLAT 1      TUDOR STREET            NaN
#
#               Town/City               District                 County
# 0         MILTON KEYNES          MILTON KEYNES          MILTON KEYNES
# 1            SUNDERLAND             SUNDERLAND          TYNE AND WEAR
# 2            COLCHESTER              BRAINTREE                  ESSEX
# 3              SOLIHULL               SOLIHULL          WEST MIDLANDS
# 4         BRIERLEY HILL                 DUDLEY          WEST MIDLANDS
# ...                 ...                    ...                    ...
# 26541199        PENARTH  THE VALE OF GLAMORGAN  THE VALE OF GLAMORGAN
# 26541200       ST ASAPH           DENBIGHSHIRE           DENBIGHSHIRE
# 26541201      BLACKWOOD             CAERPHILLY             CAERPHILLY
# 26541202        PENARTH  THE VALE OF GLAMORGAN  THE VALE OF GLAMORGAN
# 26541203    ABERGAVENNY          MONMOUTHSHIRE          MONMOUTHSHIRE
#
# [26541204 rows x 8 columns]

# %% [markdown]
# PPD Category Type имеет два типа транзакций, но учитывая, что id уникальные, данные корректны.

# %%
#теперь сгруппируем транзакции по колонкам, соответствующим адресу и типу собственности
#и посчитаем их количество в группах. Это и будет число продаж данной собственности
df0 = df0.groupby(['Property Type', 'PAON', 'SAON', 'Street', 'Locality',
       'Town/City', 'District', 'County']).size()

# %%
#res.index = res.index.to_flat_index()

# %%
#res.index.get_level_values(0)

# %%
#Находим собственность проданную более 1 раза, и обнуляем иерархический индекс(полученный при группировке)
res2 = df0[df0 > 1].reset_index()

# %%
#найдено 359291 объект
res2.rename(columns={0: 'times_sold'}, inplace=True)
res2
# Out:
#        Property Type           PAON            SAON           Street  \
# 0                  D              1  AGATHA COTTAGE    OXFORD SQUARE
# 1                  D              1   ANTIQUA HOUSE    SNOWBELL ROAD
# 2                  D              1  BAILEY COTTAGE     ANDREWS YARD
# 3                  D              1   BASEMENT FLAT    SOUTH TERRACE
# 4                  D              1   BEECH COTTAGE  DE BRIANE CLOSE
# ...              ...            ...             ...              ...
# 359286             T         YSTRAD          FLAT 4      HIGH STREET
# 359287             T   ZEITAL HOUSE             145  BOW COMMON LANE
# 359288             T  ZION COTTAGES               1      HIGH STREET
# 359289             T  ZION COTTAGES               2     RANTERS LANE
# 359290             T  ZION COTTAGES               3      HIGH STREET
#
#                      Locality           Town/City             District  \
# 0                  WATCHFIELD             SWINDON  VALE OF WHITE HORSE
# 1                  KINGSNORTH             ASHFORD              ASHFORD
# 2       ASCOTT UNDER WYCHWOOD     CHIPPING NORTON     WEST OXFORDSHIRE
# 3                      BOSTON              BOSTON               BOSTON
# 4             HAZELBURY BRYAN  STURMINSTER NEWTON         NORTH DORSET
# ...                       ...                 ...                  ...
# 359286      LLANDRINDOD WELLS   LLANDRINDOD WELLS                POWYS
# 359287                 LONDON              LONDON        TOWER HAMLETS
# 359288               SOUTHSEA             WREXHAM              WREXHAM
# 359289              GOUDHURST           CRANBROOK      TUNBRIDGE WELLS
# 359290               SOUTHSEA             WREXHAM              WREXHAM
#
#                 County  times_sold
# 0          OXFORDSHIRE           3
# 1                 KENT           2
# 2          OXFORDSHIRE           3
# 3         LINCOLNSHIRE           2
# 4               DORSET           4
# ...                ...         ...
# 359286           POWYS           2
# 359287  GREATER LONDON           2
# 359288         WREXHAM           3
# 359289            KENT           3
# 359290         WREXHAM           2
#
# [359291 rows x 9 columns]

# %%
res2[res2['times_sold']>10]
# Out:
#        Property Type              PAON            SAON            Street  \
# 115287             F      BIRCHMOOR, 2        FLAT 1-6  ST MICHAELS ROAD
# 138563             F  CHURCHGATE COURT          FLAT 3        CHURCHGATE
# 168836             F        FRESH, 138  APARTMENT 1008     CHAPEL STREET
#
#         Locality  Town/City   District              County  times_sold
# 115287  AIGBURTH  LIVERPOOL  LIVERPOOL          MERSEYSIDE          11
# 138563  BRAMHOPE      LEEDS      LEEDS      WEST YORKSHIRE          11
# 168836   SALFORD    SALFORD    SALFORD  GREATER MANCHESTER          14

# %%
res2.to_csv('/content/drive/MyDrive/datasets/pd_pred_pandas.csv')

# %%
#пометим загруженный датасет на удаление из памяти(хотя мгновенное удаление и не гарантируется)
del [[res2, df0]]

# %%
import gc
gc.collect()
# Out:
# 100

# %% [markdown]
# # Чтобы использовать меньше оперативной памяти и загрузить весь датасет, будем использовать DASK. DASK позволяет хранить датасет на жестком диске и использовать существенно меньше RAM. Ценой этому является меньшая производительность, поскольку данные загружаются с диска. DASK имеет аналогичный pandas интерфейс, поэтому код практически не изменится.

# %%
# !python -m pip install dask[dataframe] --upgrade
# Out:
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.7/dist-packages (2.12.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]) (1.2.0)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]) (1.21.5)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]) (2022.2.0)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]) (0.11.2)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->dask[dataframe]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->dask[dataframe]) (2018.9)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[dataframe]) (0.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->dask[dataframe]) (1.15.0)

# %%
import numpy as np
import pandas as pd

import dask.dataframe as dd
import dask.array as da
import dask.bag as db

# %%
df = dd.read_csv('/content/drive/MyDrive/datasets/pp-complete.csv', header=None)

# %%
df = df.rename(columns={
    0: 'id',
    1: 'Price',
    2: 'Date of Transfer',
    3: 'Postcode',
    4: 'Property Type',
    5: 'Old/New',
    6: 'Duration',
    7: 'PAON',
    8: 'SAON',
    9: 'Street', 
    10: 'Locality', 
    11: 'Town/City', 
    12: 'District',
    13: 'County', 
    14: 'PPD Category Type', 
    15: 'Record Status'})

# %%
df.head()
# Out:
#                                        id  Price  Date of Transfer  Postcode  \
# 0  {F887F88E-7D15-4415-804E-52EAC2F10958}  70000  1995-07-07 00:00  MK15 9HP
# 1  {40FD4DF2-5362-407C-92BC-566E2CCE89E9}  44500  1995-02-03 00:00   SR6 0AQ
# 2  {7A99F89E-7D81-4E45-ABD5-566E49A045EA}  56500  1995-01-13 00:00   CO6 1SQ
# 3  {28225260-E61C-4E57-8B56-566E5285B1C1}  58000  1995-07-28 00:00   B90 4TG
# 4  {444D34D7-9BA6-43A7-B695-4F48980E0176}  51000  1995-06-28 00:00   DY5 1SA
#
#   Property Type Old/New Duration PAON SAON            Street       Locality  \
# 0             D       N        F   31  NaN     ALDRICH DRIVE         WILLEN
# 1             T       N        F   50  NaN       HOWICK PARK     SUNDERLAND
# 2             T       N        F   19  NaN  BRICK KILN CLOSE     COGGESHALL
# 3             T       N        F   37  NaN  RAINSBROOK DRIVE        SHIRLEY
# 4             S       N        F   59  NaN        MERRY HILL  BRIERLEY HILL
#
#        Town/City       District         County PPD Category Type Record Status
# 0  MILTON KEYNES  MILTON KEYNES  MILTON KEYNES                 A             A
# 1     SUNDERLAND     SUNDERLAND  TYNE AND WEAR                 A             A
# 2     COLCHESTER      BRAINTREE          ESSEX                 A             A
# 3       SOLIHULL       SOLIHULL  WEST MIDLANDS                 A             A
# 4  BRIERLEY HILL         DUDLEY  WEST MIDLANDS                 A             A

# %%
res = df.groupby(['Property Type', 'PAON', 'SAON', 'Street', 'Locality',
       'Town/City', 'District', 'County']).size().compute()

# %%
res2 = res[res > 1].reset_index()

# %%
res2.rename(columns={0: 'times_sold'}, inplace=True)
res2
# Out:
#        Property Type                 PAON                 SAON  \
# 0                  D                   10          APARTMENT 1
# 1                  D                   10               FLAT C
# 2                  D                   11               FLAT 1
# 3                  D                   18    GROUND FLOOR FLAT
# 4                  D                   18  LAND TO THE REAR OF
# ...              ...                  ...                  ...
# 359286             S              MOORHEY                    2
# 359287             T             THE BARN                    2
# 359288             F  BLOCK 3 THE RISINGS         APARTMENT 35
# 359289             O        DYFFRYN COURT               UNIT 7
# 359290             O    RIBBLESDALE HOUSE                    6
#
#                      Street        Locality  Town/City              District  \
# 0           ALEXANDRA DRIVE       LIVERPOOL  LIVERPOOL             LIVERPOOL
# 1           LEAMINGTON PARK          LONDON     LONDON                EALING
# 2               QUEENS ROAD        RICHMOND   RICHMOND  RICHMOND UPON THAMES
# 3                SOUTH TOWN       DARTMOUTH  DARTMOUTH            SOUTH HAMS
# 4       LAND TO THE REAR OF       ROSETREES  LYMINGTON            NEW FOREST
# ...                     ...             ...        ...                   ...
# 359286             LEA LANE        LEA TOWN    PRESTON               PRESTON
# 359287    DISHFORTH VILLAGE       DISHFORTH     THIRSK             HARROGATE
# 359288          BRIDGE ROAD  OLD ST MELLONS    CARDIFF               CARDIFF
# 359289        MOORHEN CLOSE    SWANSEA VALE    SWANSEA               SWANSEA
# 359290         STATION ROAD     GRASSINGTON    SKIPTON                CRAVEN
#
#                  County  times_sold
# 0            MERSEYSIDE           2
# 1        GREATER LONDON           2
# 2        GREATER LONDON           3
# 3                 DEVON           3
# 4             HAMPSHIRE           2
# ...                 ...         ...
# 359286       LANCASHIRE           2
# 359287  NORTH YORKSHIRE           2
# 359288          CARDIFF           2
# 359289          SWANSEA           2
# 359290  NORTH YORKSHIRE           2
#
# [359291 rows x 9 columns]

# %%
#Получен результат аналогичный Pandas(по количеству строк и по трем наиболее продаваемым собственностям)
res2[res2['times_sold']>10]
# Out:
#        Property Type              PAON            SAON            Street  \
# 75441              F      BIRCHMOOR, 2        FLAT 1-6  ST MICHAELS ROAD
# 144521             F  CHURCHGATE COURT          FLAT 3        CHURCHGATE
# 320204             F        FRESH, 138  APARTMENT 1008     CHAPEL STREET
#
#         Locality  Town/City   District              County  times_sold
# 75441   AIGBURTH  LIVERPOOL  LIVERPOOL          MERSEYSIDE          11
# 144521  BRAMHOPE      LEEDS      LEEDS      WEST YORKSHIRE          11
# 320204   SALFORD    SALFORD    SALFORD  GREATER MANCHESTER          14

# %%
res2.to_csv('/content/drive/MyDrive/datasets/pd_pred_dask.csv')
